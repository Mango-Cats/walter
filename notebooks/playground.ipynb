# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

project_root = Path().resolve().parent
sys.path.append(str(project_root))

# %%
import scripts.preprocessing as pre

fda_df = pre.master_maker()
fda_set = set(fda_df["Brand Name"])

# This should be true since, after cleaning, the result must be the
# set of all unique brand names.
assert len(fda_set) == fda_df.shape[0]

# %%
# TEST FOR noise.py
import pandas as pd
from scripts.utils import finder
import scripts.noise as noise

sample_file = finder("sample_true_lasa.csv")
sample_true_df = pd.read_csv(str(sample_file))

lasa_set = noise.get_lasa_set(sample_true_df)

assert len(lasa_set) == 20

noise.make_noise(fda_df=fda_df, sample_true_df, n=3)
# Out:
#    Drug Name 1  Drug Name 2
# 0    Brexel 20      Geokast
# 1    Brexel 20  Olantero 10
# 2      Geokast    Brexel 20
# 3      Geokast  Olantero 10
# 4  Olantero 10    Brexel 20
# 5  Olantero 10      Geokast
